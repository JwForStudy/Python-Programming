# %% [markdown]
# <a href="https://colab.research.google.com/github/JwForStudy/Python-Programming/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_4%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4강 2절

# %% [markdown]
# ## 별 삼각형 출력하기

# %%
print("   *")
print("  ***")
print(" *****")
print("*******")
# Out:
#    *
#   ***
#  *****
# *******

# %% [markdown]
# ## 원뿔의 부피&겉넓이 계산 프로그램 5

# %%
rad = int(input())

print(type(rad))
print(rad)
# Out:
# 10
# <class 'int'>
# 10

# %%
# 원뿔 부피 및 겉넓이 계산 프로그램
rad = int(input('반지름을 입력하세요: '))
hei = int(input('높이를 입력하세요: '))
sla = pow(rad ** 2 + hei ** 2, 0.5)
#부피 & 겉넓이 출력
vol = 1 / 3 * 3.14 * rad ** 2 * hei
suf = 3.14 * rad ** 2 + 3.14 * rad * sla
print("원뿔의 부피는", str(vol) + "입니다.", sep = ' : ')
print("원뿔의 겉넓이는", str(suf) + "입니다.", sep = ' : ')
# Out:
# 반지름을 입력하세요: 10
# 높이를 입력하세요: 24
# 원뿔의 부피는 : 2512.0입니다.
# 원뿔의 겉넓이는 : 1130.4입니다.
